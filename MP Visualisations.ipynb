# %%
import numpy as np               # used for multidimensional arrays
import pandas as pd              # used for import the dataset
import matplotlib.pyplot as plt  # used for visualising graphs
import seaborn as sns

# %%
cars = pd.read_csv("cars_dataset 2.csv")

# %%
cars.head()
# Out:
#   model  year  price transmission  mileage fuelType    tax   mpg  engineSize  \
# 0    A1  2017  12500       Manual    15735   Petrol  150.0  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20.0  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30.0  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145.0  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145.0  49.6         1.0
#
#    Make
# 0  audi
# 1  audi
# 2  audi
# 3  audi
# 4  audi

# %%
cars.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# Make            0
# dtype: int64

# %%
cars.shape
# Out:
# (72435, 10)

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.set_title('transmission vs year')
sns.lineplot(ax=ax, data=cars, x='year', y='transmission')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.set_title('mileage vs year')
sns.lineplot(ax=ax, data=cars, x='year', y='mileage')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.set_title('fuelType vs year')
sns.lineplot(ax=ax, data=cars, x='year', y='fuelType')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.set_title('mpg vs year')
sns.lineplot(ax=ax, data=cars, x='year', y='mpg')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.set_title('engineSize vs year')
sns.lineplot(ax=ax, data=cars, x='year', y='engineSize')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.set_title('Make vs year')
sns.lineplot(ax=ax, data=cars, x='year', y='Make')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.set_title('tax vs year')
sns.lineplot(ax=ax, data=cars, x='year', y='tax')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.set_title('price vs year')
sns.lineplot(ax=ax, data=cars, x='year', y='price')
plt.show()
